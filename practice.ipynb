# %%
import pandas as pd
df=pd.read_csv('students_data.csv')

# %%
#Display the last 5 rows.
df.tail(6)
# Out:
#     StudentID   Name  Gender  Age  Class  Math  English  Science  Computer  \
# 9          10  Meena  Female   16     10    92       90       89        94
# 10         11  Rohit    Male   15      9    74       78       76        80
# 11         12  Pooja  Female   17     11    89       85       87        90
# 12         13  Sahil    Male   16     10    66       68       64        72
# 13         14  Kavya  Female   15      9    91       93       95        97
# 14         15   Deep    Male   17     11    58       62       61        59
#
#        City
# 9     Delhi
# 10   Mumbai
# 11  Kolkata
# 12  Chennai
# 13    Delhi
# 14   Mumbai

# %%
#Display the last 5 rows.
df.tail(5)
# Out:
#     StudentID   Name  Gender  Age  Class  Math  English  Science  Computer  \
# 10         11  Rohit    Male   15      9    74       78       76        80
# 11         12  Pooja  Female   17     11    89       85       87        90
# 12         13  Sahil    Male   16     10    66       68       64        72
# 13         14  Kavya  Female   15      9    91       93       95        97
# 14         15   Deep    Male   17     11    58       62       61        59
#
#        City
# 10   Mumbai
# 11  Kolkata
# 12  Chennai
# 13    Delhi
# 14   Mumbai

# %%
#Display the first 5 rows
df.head(6)
# Out:
#    StudentID   Name  Gender  Age  Class  Math  English  Science  Computer  \
# 0          1   Amit    Male   16     10    78       85       80        90
# 1          2   Riya  Female   15      9    88       92       84        95
# 2          3  Rahul    Male   17     11    67       70       72        60
# 3          4  Sneha  Female   16     10    90       88       91        93
# 4          5  Arjun    Male   15      9    56       60       58        65
# 5          6  Priya  Female   17     11    95       94       96        98
#
#       City
# 0  Kolkata
# 1    Delhi
# 2   Mumbai
# 3  Kolkata
# 4  Chennai
# 5    Delhi

# %%
#Find the shape of the dataset.
df.shape
# Out:
# (15, 10)

# %%
#Show all column names.

# %%
#Check the data types of each column#.

# %%
#Find the mean of the "Age" column.

# %%
#display only the Name column.

# %%
#Show students who are 16 years old.

# %%
#Show only Female students.

# %%
#Show students from Kolkata.

# %%
#Show students from Class 10.

# %%
#Show students who scored more than 80 in Math.

# %%
#Show Female students who are 15 years old.

# %%
#Show students who scored less than 70 in Science.
